# %% [markdown]
# <a href="https://colab.research.google.com/github/OlgaAlexan/proba/blob/main/28_08_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame({'x':[1,3,2],'y':[2,4,1]})

# %%
df
# Out:
#    x  y
# 0  1  2
# 1  3  4
# 2  2  1

# %%
df.drop(1,axis=0,inplace=True)

# %%
df
# Out:
#    x  y
# 0  1  2
# 2  2  1

# %%
df.reset_index(drop=True)
# Out:
#    y
# 0  2
# 1  1

# %%
del df['x']

# %%
df
# Out:
#    y
# 0  2
# 2  1

# %%
df1=pd.DataFrame({'x':[1,3,2],'y':[2,4,1]})

# %%
df2=pd.DataFrame({'x':[3,1,2],'y':[0,2,2]})

# %%
print(df1>=df2)
# Out:
#        x      y
# 0  False   True
# 1   True   True
# 2   True  False

# %%
df1[df1>1]
# Out:
#      x    y
# 0  NaN  2.0
# 1  3.0  4.0
# 2  2.0  NaN

# %%
df2[(df2<2)&(df2>0)]
# Out:
#      x   y
# 0  NaN NaN
# 1  1.0 NaN
# 2  NaN NaN

# %%
df2[(df2<1)|(df2>2)]
# Out:
#      x    y
# 0  3.0  0.0
# 1  NaN  NaN
# 2  NaN  NaN

# %%
data={'Имя':['anna','boris',None,'john'],'age':[25,30,28,None]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      Имя   age
# 0   anna  25.0
# 1  boris  30.0
# 2   None  28.0
# 3   john   NaN

# %%
х=df.isnull()

# %%
df.isnull().loc[x["Имя"]==True]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-4eb7577cd547> in <cell line: 1>()
# ----> 1 df.isnull().loc[x["Имя"]==True]
#
# NameError: name 'x' is not defined
